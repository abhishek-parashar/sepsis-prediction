# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlp
# %matplotlib inline

# %%
require 'csv'

psv_file  = ARGV[0]
csv_loc   = ARGV[1]

if psv_file =~ /psv/ && csv_loc =~ /csv/
  CSV.open(csv_loc, "wb") do |csv|
    File.open(psv_file, "r").each_line do |line|
      row = line.split('|')
      csv << row
    end
  end
else
  puts "USAGE: psv2csv.rb ['E:\Yukti\Competitions\SIH 2020\DATA\training\p000001.psv'] ['E:\Yukti\Competitions\SIH 2020\DATA']"
end
# Out:
#   File "<ipython-input-2-46666dd8910c>", line 1
#     require 'csv'
#                 ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv("E:/Yukti/Competitions/SIH 2020/DATA/training/p000867.psv", delimiter = '|')

# %%
data.head()
# Out:
#      HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0  88.0  100.0  35.95  121.5  79.50  61.5  10.0    NaN         0.0   NaN  ...
# 1  88.0   98.0  36.05  117.5  79.00  64.5  23.5    NaN         NaN   NaN  ...
# 2  88.5  100.0  35.95  111.0  70.50  53.5  23.0    NaN        -2.0   NaN  ...
# 3  88.0   95.5  36.25  104.0  68.83  55.0  28.5    NaN         NaN   NaN  ...
# 4  88.0   96.0  36.40   88.0  61.00  49.0  22.0    NaN        -1.0   NaN  ...
#
#    WBC  Fibrinogen  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  \
# 0  NaN         NaN        NaN  55.87       1      0      1        -69.7
# 1  NaN         NaN        NaN  55.87       1      0      1        -69.7
# 2  NaN         NaN        NaN  55.87       1      0      1        -69.7
# 3  NaN         NaN        NaN  55.87       1      0      1        -69.7
# 4  NaN         NaN        NaN  55.87       1      0      1        -69.7
#
#    ICULOS  SepsisLabel
# 0       5            0
# ...

# %%
import csv
readCSV = csv.reader(data, delimiter='|')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 41 columns):
# HR                  27 non-null float64
# O2Sat               27 non-null float64
# Temp                17 non-null float64
# SBP                 27 non-null float64
# MAP                 27 non-null float64
# DBP                 19 non-null float64
# Resp                27 non-null float64
# EtCO2               0 non-null float64
# BaseExcess          3 non-null float64
# HCO3                1 non-null float64
# FiO2                2 non-null float64
# pH                  6 non-null float64
# PaCO2               3 non-null float64
# SaO2                0 non-null float64
# AST                 0 non-null float64
# BUN                 1 non-null float64
# Alkalinephos        0 non-null float64
# Calcium             1 non-null float64
# Chloride            1 non-null float64
# Creatinine          1 non-null float64
# Bilirubin_direct    0 non-null float64
# ...

# %%
data.describe()
# Out:
#                HR       O2Sat       Temp         SBP         MAP  DBP  \
# count   49.000000   44.000000  10.000000   42.000000   42.000000  0.0
# mean   101.571429   91.477273  36.778000  126.809524   87.261905  NaN
# std      9.594378    3.460667   0.421078   22.422482   21.270465  NaN
# min     76.000000   85.000000  36.110000   78.000000   44.000000  NaN
# 25%     98.000000   89.000000  36.515000  111.875000   76.330000  NaN
# 50%    104.000000   91.000000  36.725000  128.000000   87.915000  NaN
# 75%    108.000000   93.000000  37.110000  138.750000   96.670000  NaN
# max    117.000000  100.000000  37.440000  181.000000  141.330000  NaN
#
#             Resp  EtCO2  BaseExcess      HCO3  ...        WBC  Fibrinogen  \
# count  50.000000    0.0    7.000000   2.00000  ...   2.000000         0.0
# mean   24.820000    NaN   20.714286  46.50000  ...  10.200000         NaN
# std     4.106689    NaN    2.138090   2.12132  ...   6.363961         NaN
# ...

# %%
filenames = []
with open('output_file', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
import os
import glob
import pandas
def concatenate(indir = "E:\\Yukti\\Competitions\\SIH 2020\\DATA\\training", outfile = "E:\\Yukti\\Competitions\\SIH 2020\\DATA\\Training Data.csv"):
    os.chdir(indir)
    fileList = glob.glob("*.psv")
    dfList = []
    for filename in fileList:
        print(filename)
        df = pandas.read_csv(filename, delimiter = '|')
        df.drop(df.index[0], inplace = True)
        dfList.append(df)
        concatDf = pandas.concat(dfList, axis=0)
        concatDf.to_csv(outfile)

# %%
concatenate()
# Out:
# p000001.psv
# p000002.psv
# p000003.psv
# p000004.psv
# p000005.psv
# p000006.psv
# p000007.psv
# p000008.psv
# p000009.psv
# p000010.psv
# p000011.psv
# p000012.psv
# p000013.psv
# p000014.psv
# p000015.psv
# p000016.psv
# p000017.psv
# p000018.psv
# p000019.psv
# p000020.psv
# p000021.psv
# p000022.psv
# p000023.psv
# p000024.psv
# p000025.psv
# p000026.psv
# p000027.psv
# p000028.psv
# p000029.psv
# p000030.psv
# p000031.psv
# p000032.psv
# p000033.psv
# p000034.psv
# p000035.psv
# p000036.psv
# p000037.psv
# p000038.psv
# p000039.psv
# p000040.psv
# p000041.psv
# p000042.psv
# p000043.psv
# p000044.psv
# p000045.psv
# p000046.psv
# p000047.psv
# p000048.psv
# p000049.psv
# p000050.psv
# p000051.psv
# p000052.psv
# p000053.psv
# p000054.psv
# p000055.psv
# p000056.psv
# p000057.psv
# p000058.psv
# p000059.psv
# p000060.psv
# p000061.psv
# p000062.psv
# p000063.psv
# p000064.psv
# p000065.psv
# p000066.psv
# p000067.psv
# p000068.psv
# p000069.psv
# p000070.psv
# p000071.psv
# ...
